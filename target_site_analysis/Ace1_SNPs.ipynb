# %%
import malariagen_data

# %%
ag3 = malariagen_data.Ag3(pre = True)

# %%
sample_set = '1246-VO-TZ-KABULA-VMF00185'
transcript = 'AGAP001356-RA'

# %%
snp_freq = ag3.snp_allele_frequencies(
    transcript,
    cohorts = 'admin1_month',
    sample_sets = sample_set
).query("effect == 'NON_SYNONYMOUS_CODING' & max_af > 0.01")

snp_freq
# Out:
# ...
# Compute SNP effects:   0%|          | 0/2196 [00:00<?, ?it/s]
#                                                  pass_gamb_colu_arab  \
# contig position ref_allele alt_allele aa_change
# 2R     3489316  T          C          F35S                      True
#        3489360  G          T          A50S                      True
#        3489390  G          A          A60T                      True
#        3489397  T          G          V62G                      True
#        3489405  G          T          A65S                     False
#        3491875  A          T          E213D                     True
#        3492176  C          A          L314M                     True
#        3492832  G          T          E477D                    False
#        3493415  G          A          E650K                     True
#        3493739  T          C          I722T                     True
#        3493765  G          A          A731T                     True
#
# ...
